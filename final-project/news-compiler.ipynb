# %%
import requests
from lxml import html
from collections import Counter

"""This program uses the requests and lxml libraries for web scrapping. 
It extracts headlines from major news outlets and compiles them"""

'''Stop words are filtered out. This list is from the Stanford NLP Group'''
stop_words = ["a", "an", "and", "how", "what", "why", "are", "as", "about", "after", "what", "at", "be", "by", "for", "from",
               "has", "he", "in", "is", "it", "its", "of", "on", "that", "the",
               "to", "was", "were", "will", "with", "i", "I"]

def main():
    news= {'BBC':bbc(), 'NYTimes':nytimes(), 'GoogleNews':google(), 'Reuters':reuters()}
    most_headlines = max(iter(news.keys()), key=lambda k: len(news[k]))
    proper_nouns_master= {}
    
    headlines_used = {'BBC':[], 'NYTimes':[], 'GoogleNews':[], 'Reuters':[]}
 
    for current_outlet in news.keys():
        for headline in news[current_outlet]:
            headlines_used[current_outlet].append(headline)
            print(headline+" -"+current_outlet)
            kw = keywords(headline)
            pn = proper_nouns(headline)
            for name in pn:
                if name in proper_nouns_master.keys():
                    proper_nouns_master[name]+=1
            else:
                    proper_nouns_master[name]=1


            for news_outlet in news.keys():
                if news_outlet is not current_outlet:
                    for headline_1 in news[news_outlet]:
                        if headline_1 not in headlines_used[news_outlet]:
                            kw_1 = keywords(headline_1)
                            pn_1 = proper_nouns(headline_1)
                            for name in pn_1:
                                if name in proper_nouns_master.keys():
                                    proper_nouns_master[name]+=1
                                else:
                                    proper_nouns_master[name]=1
                            keywords_similarity = similarity(kw, kw_1)
                            proper_nouns_similarity = similarity(pn, pn_1)
                            if keywords_similarity>= 0.1:
                                if news_outlet is not "NYTimes" and current_outlet is not "NYTimes":
                                    if proper_nouns_similarity>= 0.3:
                                        headlines_used[news_outlet].append(headline)
                                        print(headline_1+" -"+news_outlet)
                                else: 
                                    headlines_used[news_outlet].append(headline)
                                    print(headline_1+" -"+news_outlet)
            print("\n")
            
    print("The most common terms in the news are:")
    most_common = (Counter.most_common(proper_nouns_master, 5))
    for i,j in most_common:
        print(i+" which occurs "+str(j)+" times.")
        
    







#Checks what percentage similar the contents of two sets are
def similarity(set1, set2):
    if len(set1) is 0 or len(set2) is 0:
        return 0
    intersection = set1 & set2
    if len(set1)>len(set2):
        return len(intersection)/len(set1)
    else:
        return len(intersection)/len(set2)



def unpunctuated(text):
	edited_text= text
	illegal_chars= [".", ",", "\'s", ":", ";", "\"", "\'", "?", "!", "   "] #"'s" removed before "/'"
	for i in illegal_chars:
		edited_text = edited_text.replace(i , "")    
	return edited_text


#Returns keywords in a headline
def keywords(text):
    keywords=set()
    edited_text= unpunctuated(text)
    words=set(edited_text.split())
    for word in words:
        if word not in stop_words:
            keywords.add(word)
    return keywords


#Returns proper nouns in a headline
def proper_nouns(text):
    edited_text= unpunctuated(text)
    words=set(edited_text.split())
    proper_nouns_lst = [x for x in words if x[0].isupper()]
    proper_nouns= set(proper_nouns_lst)
    pn_edited = []
    
    for noun in proper_nouns: 
        lowercase = noun.lower()
        if lowercase not in stop_words:
            pn_edited.append(noun)
    result = set(pn_edited)
    return result

#Removes indents from text extracted from the site HTML
def remove_indents(text):
	indents= ["\n", "\t", "  "]
	new_text=text
	for i in indents:
		new_text = new_text.replace(i,"")

	return new_text


#Extract Headlines from NYTimes
def nytimes():
    response = requests.get("http://www.nytimes.com")
    if (response.status_code == 200):
        pagehtml = html.fromstring(response.text)
        NYTimes = pagehtml.xpath('//article[@class="story theme-summary"]/h2[@class="story-heading"]/a/text()')
        NYTimes.append(pagehtml.xpath('//article[@class="story theme-summary lede"]/h2[@class="story-heading"]/a/text()')[0])
    return NYTimes



#Extract Headlines from GoogleNews
def google():
    response = requests.get("http://news.google.com")
    if (response.status_code == 200):     
        pagehtml = html.fromstring(response.text)
        GoogleNews = pagehtml.xpath('//h2[@class="esc-lead-article-title"] \
                                    /a/span[@class="titletext"]/text()')
    return GoogleNews

#Extract Headlines from Reuters
def reuters():
    response = requests.get("http://www.reuters.com/news/archive/topNews?view=page")
    if (response.status_code == 200):
        pagehtml = html.fromstring(response.text)
        reuters_raw= pagehtml.xpath('//h3[@class="story-title"]/text()')
        reuters=[remove_indents(x) for x in reuters_raw]
    return reuters

#Extract headlines from BBC
def bbc():
    response = requests.get("http://www.bbc.com/news")
    if (response.status_code == 200):
        pagehtml = html.fromstring(response.text)
        bbc= pagehtml.xpath('//a[@class="gs-c-promo-heading nw-o-link-split__anchor gs-o-faux-block-link__overlay-link gel-paragon-bold"]/h3[@class="gs-c-promo-heading__title gel-paragon-bold nw-o-link-split__text"]/text()')
        bbc+= pagehtml.xpath('//a[@class="gs-c-promo-heading nw-o-link-split__anchor gs-o-faux-block-link__overlay-link gel-pica-bold"]/h3[@class="gs-c-promo-heading__title gel-pica-bold nw-o-link-split__text"]/text()')
        bbc_set = set(bbc)
        return(bbc_set)

"""
#Extract Headlines from CNN [ERROR NOT WORKING]
response = requests.get("http://www.cnn.com")
if (response.status_code == 200):
	pagehtml = html.fromstring(response.text)

	CNN= pagehtml.xpath('ul[@class="cn cn-list-xs cn--idx-2 cn-container_4037A43D-2B70-57AC-A8A8-74FDC9F26490 cn--expandable cn--collapsed"]/h3[@class="cd__headline"]/a/span[@class="cd__headline-text"]/text()')
	#print(pagehtml.xpath('//*[@id="homepage1-zone-1"]/div[2]/div/div[1]/ul/article[2]/div/div/h3/a/span[1]/text()'))

print("\n".join(CNN))"""




main()
# Out:
# 'Humble as hell and one of the bros' -BBC
#
#
# Lochte 'had suicidal thoughts' after Rio -BBC
#
#
# Peacock trashes liquor store in California -BBC
#
#
# Marriage 'provides a health boost' -BBC
#
#
# Teenager Ostapenko shocks Wozniacki -BBC
#
#
# Lions gameplan in 'infancy' before Blues -BBC
#
#
# Working with an invisible disability -BBC
#
#
# How dinosaurs delayed Haim's new album -BBC
# Cosby Accuser Describes How She Once ‘Trusted Him’ -NYTimes
#
#
# Attacker's uncle: I feel ashamed -BBC
#
#
# Groom 'choked bride' in wedding gifts row -BBC
#
#
# Why is there still no US envoy to UK? -BBC
# Leaked NSA report highlights deep flaws in US elections -GoogleNews
# U.S., Mexico reach sugar pact despite U.S. producer resistance -Reuters
# U.S. says China likely to build more overseas bases, maybe in Pakistan -Reuters
# After warnings, U.S. wages new strike on pro-Syria government forces -Reuters
# UK's May says ready to curb human rights laws to fight extremism -Reuters
#
#
# New pictures of bloodied Aleppo boy -BBC
# Share a New York Cab With Stranger? It’s Now Easier -NYTimes
#
#
# My parents were executed for spying -BBC
# The Secret to My Success? Antidepressants -NYTimes
#
#
# Can you learn to be a risk taker? -BBC
#
#
# What it takes to get Beyonce on a world tour -BBC
# What No One Ever Tells You About Tiny Homes -NYTimes
#
#
# Brazil's leader due before election court -BBC
# Brazil court opens case that could unseat President Temer -Reuters
#
#
# Starving residents tell of terror in Philippines -BBC
#
#
# The hidden way cities affect your mood -BBC
# The Secret to My Success? Antidepressants -NYTimes
#
#
# 'I got a hit in' - How people fought back -BBC
# Cosby Accuser Describes How She Once ‘Trusted Him’ -NYTimes
#
#
# How bad will Comey testimony be for Trump? -BBC
# Comey Told Sessions Not to Leave Him Alone With Trump -NYTimes
# Cosby Accuser Describes How She Once ‘Trusted Him’ -NYTimes
# Trump Suggests He Led Saudis to Isolate Qatar Over Terror Ties -NYTimes
# Top intelligence official told associates Trump asked him if he could intervene with Comey on FBI Russia probe -GoogleNews
# Trump jumps into worsening dispute between Qatar and powerful Arab bloc -GoogleNews
# Trump and Sessions have had heated exchanges -GoogleNews
# Trump, GOP plot path for agenda -GoogleNews
# Trump suggests border wall with solar panels -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Clooneys have twins Ella and Alexander -BBC
#
#
# Inside Islamic State's last stronghold -BBC
#
#
# New Zealand capsize in America's Cup semi -BBC
# Share a New York Cab With Stranger? It’s Now Easier -NYTimes
#
#
# Attacker shot outside Paris's Notre-Dame -BBC
# DC mayor: Honoring Paris climate deal was 'easy' decision -GoogleNews
#
#
# We missed out on voting by a day -BBC
#
#
# Indian state's 'secret' drought weapon -BBC
#
#
# Trump claims credit for Qatar isolation -BBC
# Comey Told Sessions Not to Leave Him Alone With Trump -NYTimes
# Trump Suggests He Led Saudis to Isolate Qatar Over Terror Ties -NYTimes
# Trump jumps into worsening dispute between Qatar and powerful Arab bloc -GoogleNews
# Trump and Sessions have had heated exchanges -GoogleNews
# Trump, GOP plot path for agenda -GoogleNews
# Trump suggests border wall with solar panels -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Does Facebook's Safety Check really help? -BBC
# Before You Go, Check Your Passport -NYTimes
#
#
# Two Australians killed in London attack -BBC
#
#
# Canada to change sex assault consent laws -BBC
#
#
# The Greek word that can’t be translated -BBC
# The Secret to My Success? Antidepressants -NYTimes
#
#
# Two England fans banned for Nazi gestures -BBC
#
#
# Cosby accuser 'frozen in sex attack' -BBC
# Cosby Accuser Describes How She Once ‘Trusted Him’ -NYTimes
# Bill Cosby's accuser: I felt 'humiliated' and 'confused' -GoogleNews
# Accuser describes alleged Cosby sex assault: 'I was frozen' -Reuters
#
#
# The most powerful punch of all -BBC
# The Secret to My Success? Antidepressants -NYTimes
#
#
# Latest updates: London attack -BBC
#
#
# 'Big fluffy T. rex' idea overturned -BBC
# Study casts doubt on the idea of 'big fluffy T. rex' -GoogleNews
#
#
# Seven big questions James Comey faces -BBC
# Comey Told Sessions Not to Leave Him Alone With Trump -NYTimes
#
#
# May: Human rights won't stop terror fight -BBC
# UK's May says ready to curb human rights laws to fight extremism -Reuters
#
#
# 'They think I'm a boy but I'm really not' -BBC
#
#
# Uber fires employees over harassment -BBC
# Uber Fires 20 Amid Investigation Into Workplace Culture -NYTimes
# Uber diversity chief says harassment report is 'first step of many' in fixing the company's culture -GoogleNews
#
#
# What your handwriting says about you -BBC
# What No One Ever Tells You About Tiny Homes -NYTimes
#
#
# Woman tried for boyfriend suicide texts -BBC
#
#
# Comey Told Sessions Not to Leave Him Alone With Trump -NYTimes
# Top intelligence official told associates Trump asked him if he could intervene with Comey on FBI Russia probe -GoogleNews
# Trump jumps into worsening dispute between Qatar and powerful Arab bloc -GoogleNews
# Trump and Sessions have had heated exchanges -GoogleNews
# Trump, GOP plot path for agenda -GoogleNews
# Trump suggests border wall with solar panels -GoogleNews
# Blocked by Trump on Twitter? Lawyers say he's violating your 1st Amendment rights -GoogleNews
# Cautious Comey expected in U.S. hearing on Trump-Russia probes -Reuters
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Criminal Charges in Leak About Russian Meddling in Election -NYTimes
# Russian jet fighter intercepts US bomber over Baltic Sea -GoogleNews
# Let's Talk About the Men of 'Wonder Woman' -GoogleNews
#
#
# Terrorists Deliver Their Message With Lethal Simplicity -NYTimes
#
#
# Uber Fires 20 Amid Investigation Into Workplace Culture -NYTimes
#
#
# Before You Go, Check Your Passport -NYTimes
#
#
# 28 Pastas to Make This Summer -NYTimes
#
#
# ‘You’ve Gotta Do It,’ She Texted. Then He Killed Himself. -NYTimes
#
#
# China Stands to Gain by Donating to Australian Politics -NYTimes
# U.S. says China likely to build more overseas bases, maybe in Pakistan -Reuters
#
#
# Afghanistan Reels Amid Taliban and ISIS Threats -NYTimes
#
#
# Cosby Accuser Describes How She Once ‘Trusted Him’ -NYTimes
# Bill Cosby's accuser: I felt 'humiliated' and 'confused' -GoogleNews
# Accuser describes alleged Cosby sex assault: 'I was frozen' -Reuters
#
#
# Myths About Obamacare and Insurance Markets -NYTimes
# Let's Talk About the Men of 'Wonder Woman' -GoogleNews
#
#
# Share a New York Cab With Stranger? It’s Now Easier -NYTimes
#
#
# Britain’s Voyage to Isolation -NYTimes
#
#
# The Secret to My Success? Antidepressants -NYTimes
#
#
# : Soul of a Scrapyard -NYTimes
#
#
# What No One Ever Tells You About Tiny Homes -NYTimes
# Let's Talk About the Men of 'Wonder Woman' -GoogleNews
# Hottest Alien Planet Ever Discovered Is a Real Scorcher -GoogleNews
#
#
# Trump Suggests He Led Saudis to Isolate Qatar Over Terror Ties -NYTimes
# Trump jumps into worsening dispute between Qatar and powerful Arab bloc -GoogleNews
# Trump and Sessions have had heated exchanges -GoogleNews
# Trump, GOP plot path for agenda -GoogleNews
# Trump suggests border wall with solar panels -GoogleNews
# Blocked by Trump on Twitter? Lawyers say he's violating your 1st Amendment rights -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Top intelligence official told associates Trump asked him if he could intervene with Comey on FBI Russia probe -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Trump jumps into worsening dispute between Qatar and powerful Arab bloc -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Trump and Sessions have had heated exchanges -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Leaked NSA report highlights deep flaws in US elections -GoogleNews
# U.S., Mexico reach sugar pact despite U.S. producer resistance -Reuters
# U.S. says China likely to build more overseas bases, maybe in Pakistan -Reuters
# After warnings, U.S. wages new strike on pro-Syria government forces -Reuters
#
#
# Trump, GOP plot path for agenda -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Did girlfriend's texts push teen to take his own life? -GoogleNews
#
#
# Tourists shelter in Notre Dame Cathedral as hammer-wielding assailant attacks police -GoogleNews
# Notre Dame attacker shouted 'this is for Syria' before being shot -Reuters
#
#
# DC mayor: Honoring Paris climate deal was 'easy' decision -GoogleNews
#
#
# Russian jet fighter intercepts US bomber over Baltic Sea -GoogleNews
#
#
# Trump suggests border wall with solar panels -GoogleNews
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# DeVos: Discrimination on basis of sexual orientation 'unsettled' law -GoogleNews
#
#
# Blocked by Trump on Twitter? Lawyers say he's violating your 1st Amendment rights -GoogleNews
#
#
# Texas Governor Revives Stalled Transgender Bathroom Bill -GoogleNews
#
#
# Memes are often innocent humor but can be vulgar -GoogleNews
#
#
# Uber diversity chief says harassment report is 'first step of many' in fixing the company's culture -GoogleNews
#
#
# 7 things we learned from Elon Musk's Tesla shareholder meeting -GoogleNews
#
#
# 72-hour sale: Southwest fares fall below $100 round-trip -GoogleNews
#
#
# Sears is closing 66 more stores -GoogleNews
#
#
# Apple will likely expand NFC features beyond Apple Pay with iOS 11 -GoogleNews
#
#
# The Apple exec who stole the show at WWDC 2016 explains why she will now be the face of Uber -GoogleNews
#
#
# OnePlus 5: Everything we know so far -GoogleNews
#
#
# Amazon, Mozilla and others join net neutrality protest -GoogleNews
#
#
# James Corden Pays Tribute to London: 'This Is Not a Country That Feels Afraid' -GoogleNews
#
#
# George Clooney Is a First-Time Dad at 56: 7 More Stars Who Became Fathers After 50 -GoogleNews
#
#
# Bill Cosby's accuser: I felt 'humiliated' and 'confused' -GoogleNews
# Accuser describes alleged Cosby sex assault: 'I was frozen' -Reuters
#
#
# Let's Talk About the Men of 'Wonder Woman' -GoogleNews
#
#
# The Jets won't stop until they are the youngest — and worst — team in the NFL -GoogleNews
#
#
# Marshawn Lynch: Wanted to give kids in Oakland someone to cheer -GoogleNews
#
#
# Markelle Fultz meets with Celtics, still undecided on working out for other teams -GoogleNews
#
#
# Warriors will battle complacency as much as Cavs in 'hardest game of series' -GoogleNews
#
#
# Study casts doubt on the idea of 'big fluffy T. rex' -GoogleNews
#
#
# NASA needs to develop new Mars missions now to prevent stall in exploration, organization argues -GoogleNews
#
#
# Hottest Alien Planet Ever Discovered Is a Real Scorcher -GoogleNews
#
#
# Polar Photographer Shares His View Of A Ferocious But Fragile Ecosystem -GoogleNews
#
#
# Moderate drinking may alter brain, study says -GoogleNews
#
#
# Unknown street drug blamed for deaths, dozens of overdoses in Georgia -GoogleNews
#
#
# 8 things doctors are buzzing about at the biggest cancer meeting -GoogleNews
#
#
# When should babies start sleeping in their own room? -GoogleNews
#
#
# U.S., Mexico reach sugar pact despite U.S. producer resistance -Reuters
#
#
# Cautious Comey expected in U.S. hearing on Trump-Russia probes -Reuters
#
#
# Trump seeks legislative wins to cast off shadow of Russia probes -Reuters
#
#
# Notre Dame attacker shouted 'this is for Syria' before being shot -Reuters
#
#
# U.S. says China likely to build more overseas bases, maybe in Pakistan -Reuters
#
#
# After warnings, U.S. wages new strike on pro-Syria government forces -Reuters
#
#
# UK's May says ready to curb human rights laws to fight extremism -Reuters
#
#
# Brazil court opens case that could unseat President Temer -Reuters
#
#
# Accuser describes alleged Cosby sex assault: 'I was frozen' -Reuters
#
#
# Suspect in Oregon train stabbings indicted for murder -Reuters
#
#
# The most common terms in the news are:
# Comey which occurs 203 times.
# Russia which occurs 158 times.
# Notre which occurs 158 times.
# Apple which occurs 120 times.
# Cosby which occurs 106 times.
